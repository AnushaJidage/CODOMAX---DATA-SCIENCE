# %% [markdown]
# # Codomax Data Science Internship — Module 4
#
# ## Machine Learning Basics
#
# **Duration:** Day 13 – Day 16
# **Level:** High
# **Priority:** High
#
# ### What You'll Learn
# - Understand basic Machine Learning concepts
# - Use Scikit-learn
# - Prepare features and targets
# - Split data into training and testing sets
# - Train regression and classification models
# - Make predictions
# - Evaluate model performance
# - Build beginner projects:
#   - Student Score Prediction
#   - House Price Prediction
#   - Iris Flower Classification
#
# > Run all cells from top to bottom in Google Colab.

# %% [markdown]
# # Day 13 — Machine Learning Fundamentals
#
# Machine Learning is a method of teaching computers to learn patterns from data and make predictions.
#
# ## Basic Workflow
#
# **Problem → Data → Features/Target → Train/Test Split → Train Model → Predict → Evaluate → Improve**
#
# ### Types used in this module
# - **Regression:** predicts a numerical value
# - **Classification:** predicts a category or class

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression

print("Libraries imported successfully.")

# %% [markdown]
# # Project 1 — Student Score Prediction
#
# ## Problem
# Predict a student's score based on the number of hours studied.
#
# This is a **Regression** problem because the output is numerical.

# %%
student_data = pd.DataFrame({
    "Study_Hours": [1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9],
    "Score": [28, 32, 35, 39, 45, 48, 52, 57, 61, 65, 69, 73, 77, 80, 84, 88, 92]
})

student_data.head()

# %% [markdown]
# ### Visualize the Relationship

# %%
plt.figure(figsize=(8,5))
plt.scatter(student_data["Study_Hours"], student_data["Score"])
plt.xlabel("Study Hours")
plt.ylabel("Student Score")
plt.title("Study Hours vs Student Score")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Prepare Features and Target

# %%
X = student_data[["Study_Hours"]]
y = student_data["Score"]

print("Features shape:", X.shape)
print("Target shape:", y.shape)

# %% [markdown]
# ### Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

print("Training records:", len(X_train))
print("Testing records:", len(X_test))

# %% [markdown]
# ### Train Linear Regression Model

# %%
student_model = LinearRegression()
student_model.fit(X_train, y_train)

print("Model trained successfully.")
print("Coefficient:", student_model.coef_[0])
print("Intercept:", student_model.intercept_)

# %% [markdown]
# ### Make Predictions

# %%
student_predictions = student_model.predict(X_test)

results = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": np.round(student_predictions, 2)
})

results

# %% [markdown]
# ### Evaluate the Regression Model

# %%
mae = mean_absolute_error(y_test, student_predictions)
mse = mean_squared_error(y_test, student_predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, student_predictions)

print("MAE:", round(mae, 2))
print("MSE:", round(mse, 2))
print("RMSE:", round(rmse, 2))
print("R² Score:", round(r2, 3))

# %% [markdown]
# ### Regression Metrics
# - **MAE:** average absolute prediction error
# - **MSE:** average squared error
# - **RMSE:** error in the same units as the target
# - **R²:** proportion of variance explained by the model
#
# Higher R² and lower error values generally indicate a better fit.

# %% [markdown]
# ### Predict a New Student Score

# %%
hours = 6.0
predicted_score = student_model.predict(pd.DataFrame({"Study_Hours":[hours]}))[0]

print(f"Predicted score for {hours} study hours: {predicted_score:.2f}")

# %% [markdown]
# # Day 14 — House Price Prediction
#
# ## Problem
# Predict house price using area in square feet.
#
# This is also a **Regression** problem.

# %%
house_data = pd.DataFrame({
    "Area_sqft": [600, 750, 900, 1050, 1200, 1350, 1500, 1700, 1900, 2100, 2300, 2500],
    "Price_Lakh": [28, 34, 39, 45, 51, 58, 64, 73, 82, 91, 99, 108]
})

house_data

# %%
plt.figure(figsize=(8,5))
plt.scatter(house_data["Area_sqft"], house_data["Price_Lakh"])
plt.xlabel("Area (sq ft)")
plt.ylabel("Price (Lakh)")
plt.title("House Area vs Price")
plt.grid(True)
plt.show()

# %%
X_house = house_data[["Area_sqft"]]
y_house = house_data["Price_Lakh"]

Xh_train, Xh_test, yh_train, yh_test = train_test_split(
    X_house, y_house, test_size=0.25, random_state=42
)

house_model = LinearRegression()
house_model.fit(Xh_train, yh_train)

house_predictions = house_model.predict(Xh_test)

house_results = pd.DataFrame({
    "Actual Price": yh_test.values,
    "Predicted Price": np.round(house_predictions, 2)
})

house_results

# %%
house_mae = mean_absolute_error(yh_test, house_predictions)
house_rmse = np.sqrt(mean_squared_error(yh_test, house_predictions))
house_r2 = r2_score(yh_test, house_predictions)

print("House Price Model")
print("MAE:", round(house_mae, 2))
print("RMSE:", round(house_rmse, 2))
print("R²:", round(house_r2, 3))

# %% [markdown]
# ### Predict Price for a New House

# %%
new_area = 1600

predicted_price = house_model.predict(
    pd.DataFrame({"Area_sqft":[new_area]})
)[0]

print(f"Predicted price for {new_area} sq ft: {predicted_price:.2f} lakh")

# %% [markdown]
# # Day 15 — Iris Flower Classification
#
# ## Problem
# Predict the Iris flower species from its measurements.
#
# This is a **Classification** problem.
#
# The Iris dataset has three species:
# - Setosa
# - Versicolor
# - Virginica

# %%
iris = load_iris()

iris_df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

iris_df["target"] = iris.target
iris_df["species"] = iris_df["target"].map(
    dict(enumerate(iris.target_names))
)

iris_df.head()

# %% [markdown]
# ### Inspect the Dataset

# %%
print("Shape:", iris_df.shape)
print("\nClass distribution:")
print(iris_df["species"].value_counts())

iris_df.describe()

# %% [markdown]
# ### Prepare Features and Target

# %%
X_iris = iris.data
y_iris = iris.target

Xi_train, Xi_test, yi_train, yi_test = train_test_split(
    X_iris,
    y_iris,
    test_size=0.20,
    random_state=42,
    stratify=y_iris
)

print("Training samples:", len(Xi_train))
print("Testing samples:", len(Xi_test))

# %% [markdown]
# ### Train Logistic Regression

# %%
iris_model = LogisticRegression(max_iter=300)
iris_model.fit(Xi_train, yi_train)

print("Classification model trained successfully.")

# %% [markdown]
# ### Predict Test Data

# %%
iris_predictions = iris_model.predict(Xi_test)

prediction_table = pd.DataFrame({
    "Actual": [iris.target_names[i] for i in yi_test],
    "Predicted": [iris.target_names[i] for i in iris_predictions]
})

prediction_table.head(10)

# %% [markdown]
# ### Evaluate Classification Performance

# %%
accuracy = accuracy_score(yi_test, iris_predictions)

print("Accuracy:", round(accuracy, 3))

print("\nConfusion Matrix:")
print(confusion_matrix(yi_test, iris_predictions))

print("\nClassification Report:")
print(classification_report(
    yi_test,
    iris_predictions,
    target_names=iris.target_names
))

# %% [markdown]
# ### Classification Metrics
# - **Accuracy:** proportion of predictions that are correct
# - **Precision:** how many predicted positives were correct
# - **Recall:** how many actual positives were identified
# - **F1-score:** balance between precision and recall
# - **Confusion Matrix:** shows correct and incorrect classifications

# %% [markdown]
# ### Predict a New Iris Flower

# %%
new_flower = np.array([[5.1, 3.5, 1.4, 0.2]])

predicted_class = iris_model.predict(new_flower)[0]

print("Predicted flower:",
      iris.target_names[predicted_class])

# %% [markdown]
# # Day 16 — Compare Regression and Classification
#
# | Feature | Regression | Classification |
# |---|---|---|
# | Output | Numerical value | Category/class |
# | Example | Student score | Iris species |
# | Example | House price | Pass/Fail |
# | Common beginner model | Linear Regression | Logistic Regression |
# | Metrics | MAE, RMSE, R² | Accuracy, Precision, Recall, F1 |

# %% [markdown]
# # Machine Learning Mini Project Summary
#
# ## Project 1 — Student Score Prediction
# - Input: Study Hours
# - Output: Student Score
# - Model: Linear Regression
# - Evaluation: MAE, RMSE, R²
#
# ## Project 2 — House Price Prediction
# - Input: House Area
# - Output: House Price
# - Model: Linear Regression
# - Evaluation: MAE, RMSE, R²
#
# ## Project 3 — Iris Classification
# - Inputs: Sepal and Petal Measurements
# - Output: Flower Species
# - Model: Logistic Regression
# - Evaluation: Accuracy, Confusion Matrix, Precision, Recall, F1

# %% [markdown]
# # Practice Tasks
#
# 1. Add more student records to the Student Score dataset.
# 2. Predict a score for 7.2 hours of study.
# 3. Add another house feature such as bedrooms.
# 4. Compare actual and predicted house prices.
# 5. Change the Iris train/test split to 70/30.
# 6. Compare the new Iris accuracy.
# 7. Explain why regression and classification require different metrics.
# 8. Write at least three observations from your model results.

# %% [markdown]
# # Important Beginner ML Concepts
#
# Before finishing Module 4, make sure you understand:
#
# - **Feature (X):** input variable used by the model
# - **Target (y):** value/category we want to predict
# - **Training data:** data used to learn patterns
# - **Testing data:** unseen data used for evaluation
# - **Model:** mathematical representation learned from training data
# - **Prediction:** model output for new/unseen input
# - **Overfitting:** model performs well on training data but poorly on unseen data
# - **Underfitting:** model is too simple to capture useful patterns
# - **Random state:** makes data splitting reproducible

# %% [markdown]
# # Module 4 Conclusion
#
# In this module, you completed the basic Machine Learning workflow:
#
# **Define Problem → Prepare Data → Split → Train → Predict → Evaluate → Interpret**
#
# You built:
# 1. Student Score Prediction
# 2. House Price Prediction
# 3. Iris Flower Classification
#
# This prepares you for more advanced topics such as:
# - Feature Engineering
# - Decision Trees
# - Random Forests
# - Model Selection
# - Hyperparameter Tuning
# - Cross Validation

# %% [markdown]
# # Submission Checklist
#
# Before submitting:
#
# - [ ] Run every cell successfully in Google Colab
# - [ ] Verify all model outputs
# - [ ] Review MAE, RMSE, R², Accuracy and Classification Report
# - [ ] Add your own observations
# - [ ] Save a copy in Google Drive
# - [ ] Click **Share**
# - [ ] Set **Anyone with the link → Viewer**
# - [ ] Copy your Google Colab link
# - [ ] Publish your Module 4 LinkedIn post
# - [ ] Copy your LinkedIn post link
#
# ## Submission Deliverables
#
# **Google Colab Link:**
# `Paste your Colab link here`
#
# **LinkedIn Post Link:**
# `Paste your LinkedIn post link here`
